# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mikail Farid__ <br>
# Data Scientist

# %% [markdown]
# _Data science opens the door to a myriad of opportunities. My interest is it's use especially in the health industry._

# %% [markdown]
# ### Using the print function

# %%
print("""
         # #     #   #####   #
         #  #   # #    #    # # 
         #  #   ###    #    ###
         ###    # #    #    # #
                                 """)
# Out:
#          # #     #   #####   #
#          #  #   # #    #    # #
#          #  #   ###    #    ###
#          ###    # #    #    # #

# %% [markdown]
# ***
# *  Bullet list 1
# *  Bullet list 2
#     *  Sub bullet
# ***
# 1. Numbered item
# 1. Numbered item
#     1. sub step
# ***
# ![image.png](attachment:image.png)
